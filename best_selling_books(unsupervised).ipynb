# %% [markdown]
# # Importing Necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading Data Set

# %%
df=pd.read_csv('/content/best-selling-books.csv')
df
# Out:
#                                                   Book  \
# 0                                 A Tale of Two Cities
# 1                  The Little Prince (Le Petit Prince)
# 2             Harry Potter and the Philosopher's Stone
# 3                             And Then There Were None
# 4                       Dream of the Red Chamber (紅樓夢)
# ..                                                 ...
# 169                                           The Goal
# 170                                     Fahrenheit 451
# 171                                     Angela's Ashes
# 172  The Story of My Experiments with Truth (સત્યના...
# 173                              Bridget Jones's Diary
#
#                       Author(s) Original language  First published  \
# 0               Charles Dickens           English             1859
# 1      Antoine de Saint-Exupéry            French             1943
# 2                 J. K. Rowling           English             1997
# 3               Agatha Christie           English             1939
# 4                    Cao Xueqin           Chinese             1791
# ..                          ...               ...              ...
# 169         Eliyahu M. Goldratt           English             1984
# 170                Ray Bradbury           English             1953
# 171               Frank McCourt           English             1996
# 172  Mohandas Karamchand Gandhi          Gujarati             1929
# 173              Helen Fielding           English             1996
#
#      Approximate sales in millions               Genre
# 0                            200.0  Historical fiction
# 1                            200.0             Novella
# 2                            120.0             Fantasy
# 3                            100.0             Mystery
# 4                            100.0         Family saga
# ..                             ...                 ...
# 169                           10.0                 NaN
# 170                           10.0                 NaN
# 171                           10.0                 NaN
# 172                           10.0                 NaN
# 173                           10.0                 NaN
#
# [174 rows x 6 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.shape
# Out:
# (174, 6)

# %%
df.size
# Out:
# 1044

# %%
df['Original language'].unique()
# Out:
# array(['English', 'French', 'Chinese', 'Hindi', 'Portuguese', 'Spanish',
#        'German', 'Italian', 'Norwegian', 'Russian', 'Dutch', 'Swedish',
#        'Japanese', 'Czech', 'Yiddish', 'Gujarati'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Book                              0
# Author(s)                         0
# Original language                 0
# First published                   0
# Approximate sales in millions     0
# Genre                            56
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Book, Author(s), Original language, First published, Approximate sales in millions, Genre]
# Index: []

# %%
df.head(15)
# Out:
#                                          Book                 Author(s)  \
# 0                        A Tale of Two Cities           Charles Dickens
# 1         The Little Prince (Le Petit Prince)  Antoine de Saint-Exupéry
# 2    Harry Potter and the Philosopher's Stone             J. K. Rowling
# 3                    And Then There Were None           Agatha Christie
# 4              Dream of the Red Chamber (紅樓夢)                Cao Xueqin
# 5                                  The Hobbit          J. R. R. Tolkien
# 6        The Lion, the Witch and the Wardrobe               C. S. Lewis
# 7                 She: A History of Adventure          H. Rider Haggard
# 8         Vardi Wala Gunda (वर्दी वाला गुंडा)        Ved Prakash Sharma
# 9                           The Da Vinci Code                 Dan Brown
# 10    Harry Potter and the Chamber of Secrets             J. K. Rowling
# 11   Harry Potter and the Prisoner of Azkaban             J. K. Rowling
# 12        Harry Potter and the Goblet of Fire             J. K. Rowling
# 13  Harry Potter and the Order of the Phoenix             J. K. Rowling
# 14     Harry Potter and the Half-Blood Prince             J. K. Rowling
#
#    Original language  First published  Approximate sales in millions  \
# 0            English             1859                          200.0
# 1             French             1943                          200.0
# 2            English             1997                          120.0
# 3            English             1939                          100.0
# 4            Chinese             1791                          100.0
# 5            English             1937                          100.0
# 6            English             1950                           85.0
# 7            English             1887                           83.0
# 8              Hindi             1992                           80.0
# 9            English             2003                           80.0
# 10           English             1998                           77.0
# 11           English             1999                           65.0
# 12           English             2000                           65.0
# 13           English             2003                           65.0
# 14           English             2005                           65.0
#
#                           Genre
# 0            Historical fiction
# 1                       Novella
# 2                       Fantasy
# 3                       Mystery
# 4                   Family saga
# 5                       Fantasy
# 6   Fantasy, Children's fiction
# 7                     Adventure
# 8                     Detective
# 9              Mystery thriller
# 10                      Fantasy
# 11                      Fantasy
# 12                      Fantasy
# 13                      Fantasy
# 14                      Fantasy

# %%
df.tail(15)
# Out:
#                                                   Book  \
# 159                                    The Total Woman
# 160                  Knowledge-value Revolution (知価革命)
# 161  Problems in China's Socialist Economy (中国社会主义经...
# 162                      What Color Is Your Parachute?
# 163                                     The Dukan Diet
# 164                                     The Joy of Sex
# 165                    The Gospel According to Peanuts
# 166                The Subtle Art of Not Giving a Fuck
# 167                                         Life of Pi
# 168                                   The Front Runner
# 169                                           The Goal
# 170                                     Fahrenheit 451
# 171                                     Angela's Ashes
# 172  The Story of My Experiments with Truth (સત્યના...
# 173                              Bridget Jones's Diary
#
#                       Author(s) Original language  First published  \
# 159              Marabel Morgan           English             1974
# 160              Taichi Sakaiya          Japanese             1985
# 161                  Xue Muqiao           Chinese             1979
# 162       Richard Nelson Bolles           English             1970
# 163                Pierre Dukan            French             2000
# 164                Alex Comfort           English             1972
# 165             Robert L. Short           English             1965
# 166                 Mark Manson           English             2016
# 167                 Yann Martel           English             2001
# 168        Patricia Nell Warren           English             1974
# 169         Eliyahu M. Goldratt           English             1984
# 170                Ray Bradbury           English             1953
# 171               Frank McCourt           English             1996
# 172  Mohandas Karamchand Gandhi          Gujarati             1929
# 173              Helen Fielding           English             1996
#
#      Approximate sales in millions Genre
# 159                           10.0   NaN
# 160                           10.0   NaN
# 161                           10.0   NaN
# 162                           10.0   NaN
# 163                           10.0   NaN
# 164                           10.0   NaN
# 165                           10.0   NaN
# 166                           10.0   NaN
# 167                           10.0   NaN
# 168                           10.0   NaN
# 169                           10.0   NaN
# 170                           10.0   NaN
# 171                           10.0   NaN
# 172                           10.0   NaN
# 173                           10.0   NaN

# %%
df.columns
# Out:
# Index(['Book', 'Author(s)', 'Original language', 'First published',
#        'Approximate sales in millions', 'Genre'],
#       dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=174, step=1),
#  Index(['Book', 'Author(s)', 'Original language', 'First published',
#         'Approximate sales in millions', 'Genre'],
#        dtype='object')]

# %%
df.dtypes
# Out:
# Book                              object
# Author(s)                         object
# Original language                 object
# First published                    int64
# Approximate sales in millions    float64
# Genre                             object
# dtype: object

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='most_frequent')
df['Genre'] = imputer.fit_transform(df[['Genre']]).flatten()
df
# Out:
#                                                   Book  \
# 0                                 A Tale of Two Cities
# 1                  The Little Prince (Le Petit Prince)
# 2             Harry Potter and the Philosopher's Stone
# 3                             And Then There Were None
# 4                       Dream of the Red Chamber (紅樓夢)
# ..                                                 ...
# 169                                           The Goal
# 170                                     Fahrenheit 451
# 171                                     Angela's Ashes
# 172  The Story of My Experiments with Truth (સત્યના...
# 173                              Bridget Jones's Diary
#
#                       Author(s) Original language  First published  \
# 0               Charles Dickens           English             1859
# 1      Antoine de Saint-Exupéry            French             1943
# 2                 J. K. Rowling           English             1997
# 3               Agatha Christie           English             1939
# 4                    Cao Xueqin           Chinese             1791
# ..                          ...               ...              ...
# 169         Eliyahu M. Goldratt           English             1984
# 170                Ray Bradbury           English             1953
# 171               Frank McCourt           English             1996
# 172  Mohandas Karamchand Gandhi          Gujarati             1929
# 173              Helen Fielding           English             1996
#
#      Approximate sales in millions               Genre
# 0                            200.0  Historical fiction
# 1                            200.0             Novella
# 2                            120.0             Fantasy
# 3                            100.0             Mystery
# 4                            100.0         Family saga
# ..                             ...                 ...
# 169                           10.0             Fantasy
# 170                           10.0             Fantasy
# 171                           10.0             Fantasy
# 172                           10.0             Fantasy
# 173                           10.0             Fantasy
#
# [174 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Book                             0
# Author(s)                        0
# Original language                0
# First published                  0
# Approximate sales in millions    0
# Genre                            0
# dtype: int64

# %%
df.head(20)
# Out:
#                                          Book                 Author(s)  \
# 0                        A Tale of Two Cities           Charles Dickens
# 1         The Little Prince (Le Petit Prince)  Antoine de Saint-Exupéry
# 2    Harry Potter and the Philosopher's Stone             J. K. Rowling
# 3                    And Then There Were None           Agatha Christie
# 4              Dream of the Red Chamber (紅樓夢)                Cao Xueqin
# 5                                  The Hobbit          J. R. R. Tolkien
# 6        The Lion, the Witch and the Wardrobe               C. S. Lewis
# 7                 She: A History of Adventure          H. Rider Haggard
# 8         Vardi Wala Gunda (वर्दी वाला गुंडा)        Ved Prakash Sharma
# 9                           The Da Vinci Code                 Dan Brown
# 10    Harry Potter and the Chamber of Secrets             J. K. Rowling
# 11   Harry Potter and the Prisoner of Azkaban             J. K. Rowling
# 12        Harry Potter and the Goblet of Fire             J. K. Rowling
# 13  Harry Potter and the Order of the Phoenix             J. K. Rowling
# 14     Harry Potter and the Half-Blood Prince             J. K. Rowling
# 15       Harry Potter and the Deathly Hallows             J. K. Rowling
# 16               The Alchemist (O Alquimista)              Paulo Coelho
# 17                     The Catcher in the Rye            J. D. Salinger
# 18              The Bridges of Madison County       Robert James Waller
# 19              Ben-Hur: A Tale of the Christ               Lew Wallace
#
#    Original language  First published  Approximate sales in millions  \
# 0            English             1859                          200.0
# 1             French             1943                          200.0
# 2            English             1997                          120.0
# 3            English             1939                          100.0
# 4            Chinese             1791                          100.0
# 5            English             1937                          100.0
# 6            English             1950                           85.0
# 7            English             1887                           83.0
# 8              Hindi             1992                           80.0
# 9            English             2003                           80.0
# 10           English             1998                           77.0
# 11           English             1999                           65.0
# 12           English             2000                           65.0
# 13           English             2003                           65.0
# 14           English             2005                           65.0
# 15           English             2007                           65.0
# 16        Portuguese             1988                           65.0
# 17           English             1951                           65.0
# 18           English             1992                           60.0
# 19           English             1880                           50.0
#
#                           Genre
# 0            Historical fiction
# 1                       Novella
# 2                       Fantasy
# 3                       Mystery
# 4                   Family saga
# 5                       Fantasy
# 6   Fantasy, Children's fiction
# 7                     Adventure
# 8                     Detective
# 9              Mystery thriller
# 10                      Fantasy
# 11                      Fantasy
# 12                      Fantasy
# 13                      Fantasy
# 14                      Fantasy
# 15                      Fantasy
# 16                      Fantasy
# 17                Coming-of-age
# 18                      Romance
# 19           Historical fiction

# %%
df.tail(20)
# Out:
#                                                   Book  \
# 154                                   The Lovely Bones
# 155                                         Wild Swans
# 156                                        Santa Evita
# 157                    Night (Un di Velt Hot Geshvign)
# 158                Confucius from the Heart (于丹《论语》心得)
# 159                                    The Total Woman
# 160                  Knowledge-value Revolution (知価革命)
# 161  Problems in China's Socialist Economy (中国社会主义经...
# 162                      What Color Is Your Parachute?
# 163                                     The Dukan Diet
# 164                                     The Joy of Sex
# 165                    The Gospel According to Peanuts
# 166                The Subtle Art of Not Giving a Fuck
# 167                                         Life of Pi
# 168                                   The Front Runner
# 169                                           The Goal
# 170                                     Fahrenheit 451
# 171                                     Angela's Ashes
# 172  The Story of My Experiments with Truth (સત્યના...
# 173                              Bridget Jones's Diary
#
#                       Author(s) Original language  First published  \
# 154                Alice Sebold           English             2002
# 155                  Jung Chang           English             1992
# 156         Tomás Eloy Martínez           Spanish             1995
# 157                 Elie Wiesel           Yiddish             1958
# 158                      Yu Dan           Chinese             2006
# 159              Marabel Morgan           English             1974
# 160              Taichi Sakaiya          Japanese             1985
# 161                  Xue Muqiao           Chinese             1979
# 162       Richard Nelson Bolles           English             1970
# 163                Pierre Dukan            French             2000
# 164                Alex Comfort           English             1972
# 165             Robert L. Short           English             1965
# 166                 Mark Manson           English             2016
# 167                 Yann Martel           English             2001
# 168        Patricia Nell Warren           English             1974
# 169         Eliyahu M. Goldratt           English             1984
# 170                Ray Bradbury           English             1953
# 171               Frank McCourt           English             1996
# 172  Mohandas Karamchand Gandhi          Gujarati             1929
# 173              Helen Fielding           English             1996
#
#      Approximate sales in millions    Genre
# 154                           10.0  Fantasy
# 155                           10.0  Fantasy
# 156                           10.0  Fantasy
# 157                           10.0  Fantasy
# 158                           10.0  Fantasy
# 159                           10.0  Fantasy
# 160                           10.0  Fantasy
# 161                           10.0  Fantasy
# 162                           10.0  Fantasy
# 163                           10.0  Fantasy
# 164                           10.0  Fantasy
# 165                           10.0  Fantasy
# 166                           10.0  Fantasy
# 167                           10.0  Fantasy
# 168                           10.0  Fantasy
# 169                           10.0  Fantasy
# 170                           10.0  Fantasy
# 171                           10.0  Fantasy
# 172                           10.0  Fantasy
# 173                           10.0  Fantasy

# %%
h=df.describe()
h
# Out:
#        First published  Approximate sales in millions
# count       174.000000                     174.000000
# mean       1962.522989                      30.097126
# std          64.268737                      27.957985
# min        1304.000000                      10.000000
# 25%        1947.000000                      14.000000
# 50%        1974.000000                      20.000000
# 75%        1995.000000                      36.300000
# max        2018.000000                     200.000000

# %%
k=['Book', 'Author(s)', 'Original language', 'First published',
        'Approximate sales in millions', 'Genre']
for i in k:
  j=df[i].value_counts()
  print("---------------------------------------------->",j)
# Out:
# ----------------------------------------------> Book
# Bridget Jones's Diary                        1
# A Tale of Two Cities                         1
# The Little Prince (Le Petit Prince)          1
# Harry Potter and the Philosopher's Stone     1
# And Then There Were None                     1
#                                             ..
# The Da Vinci Code                            1
# Harry Potter and the Chamber of Secrets      1
# Harry Potter and the Prisoner of Azkaban     1
# Harry Potter and the Goblet of Fire          1
# Harry Potter and the Order of the Phoenix    1
# Name: count, Length: 174, dtype: int64
# ----------------------------------------------> Author(s)
# J. K. Rowling                              7
# Suzanne Collins                            3
# Roald Dahl                                 3
# Dan Brown                                  3
# Albert Camus                               2
#                                           ..
# Stephen Hawking                            1
# Jacques-Henri Bernardin de Saint-Pierre    1
# Irving Stone                               1
# Kenneth Grahame                            1
# Margaret Mitchell                          1
# Name: count, Length: 157, dtype: int64
# ----------------------------------------------> Original language
# English       131
# Russian         6
# German          5
# French          5
# Japanese        5
# Chinese         4
# Italian         4
# Spanish         3
# Swedish         2
# Hindi           2
# Norwegian       2
# Portuguese      1
# Dutch           1
# Czech           1
# Yiddish         1
# Gujarati        1
# Name: count, dtype: int64
# ----------------------------------------------> First published
# 1979    5
# 1988    4
# 1992    4
# 1974    4
# 2000    4
#        ..
# 1304    1
# 1978    1
# 2016    1
# 1953    1
# 1859    1
# Name: count, Length: 95, dtype: int64
# ----------------------------------------------> Approximate sales in millions
# 10.0     27
# 20.0     27
# 50.0     14
# 15.0      9
# 30.0      9
# 65.0      7
# 14.0      7
# 12.0      6
# 25.0      5
# 40.0      5
# 21.0      4
# 16.0      4
# 100.0     3
# 11.0      3
# 23.0      3
# 35.0      3
# 13.0      2
# 200.0     2
# 80.0      2
# 18.0      2
# 29.0      2
# 33.0      2
# 10.5      2
# 120.0     1
# 43.0      1
# 44.0      1
# 45.0      1
# 60.0      1
# 85.0      1
# 83.0      1
# 77.0      1
# 39.0      1
# 22.5      1
# 28.0      1
# 26.0      1
# 36.0      1
# 36.4      1
# 31.5      1
# 31.0      1
# 37.0      1
# 24.0      1
# 17.0      1
# 15.2      1
# 15.3      1
# 12.1      1
# 11.5      1
# 10.4      1
# Name: count, dtype: int64
# ----------------------------------------------> Genre
# Fantasy                                                                        66
# Novel                                                                           8
# Self-help                                                                       7
# Historical fiction                                                              4
# Children's Literature                                                           4
#                                                                                ..
# Socialist realist novel                                                         1
# Mystery-thriller                                                                1
# Philosophical novel, Young adult                                                1
# Popular science, Anthropology, Astrophysics, Cosmology, Philosophy, History     1
# Bildungsroman, Historical fiction                                               1
# Name: count, Length: 80, dtype: int64

# %%
for i in k:
  f=df[i].describe()
  print(f)
  print("--------------------------------------------------")
# Out:
# count                       174
# unique                      174
# top       Bridget Jones's Diary
# freq                          1
# Name: Book, dtype: object
# -------------------------------------------
# count               174
# unique              157
# top       J. K. Rowling
# freq                  7
# Name: Author(s), dtype: object
# -------------------------------------------
# count         174
# unique         16
# top       English
# freq          131
# Name: Original language, dtype: object
# -------------------------------------------
# count     174.000000
# mean     1962.522989
# std        64.268737
# min      1304.000000
# 25%      1947.000000
# 50%      1974.000000
# 75%      1995.000000
# max      2018.000000
# Name: First published, dtype: float64
# -------------------------------------------
# count    174.000000
# mean      30.097126
# std       27.957985
# min       10.000000
# 25%       14.000000
# 50%       20.000000
# 75%       36.300000
# max      200.000000
# Name: Approximate sales in millions, dtype: float64
# -------------------------------------------
# count         174
# unique         80
# top       Fantasy
# freq           66
# Name: Genre, dtype: object
# -------------------------------------------

# %%
df
# Out:
#                                                   Book  \
# 0                                 A Tale of Two Cities
# 1                  The Little Prince (Le Petit Prince)
# 2             Harry Potter and the Philosopher's Stone
# 3                             And Then There Were None
# 4                       Dream of the Red Chamber (紅樓夢)
# ..                                                 ...
# 169                                           The Goal
# 170                                     Fahrenheit 451
# 171                                     Angela's Ashes
# 172  The Story of My Experiments with Truth (સત્યના...
# 173                              Bridget Jones's Diary
#
#                       Author(s) Original language  First published  \
# 0               Charles Dickens           English             1859
# 1      Antoine de Saint-Exupéry            French             1943
# 2                 J. K. Rowling           English             1997
# 3               Agatha Christie           English             1939
# 4                    Cao Xueqin           Chinese             1791
# ..                          ...               ...              ...
# 169         Eliyahu M. Goldratt           English             1984
# 170                Ray Bradbury           English             1953
# 171               Frank McCourt           English             1996
# 172  Mohandas Karamchand Gandhi          Gujarati             1929
# 173              Helen Fielding           English             1996
#
#      Approximate sales in millions               Genre
# 0                            200.0  Historical fiction
# 1                            200.0             Novella
# 2                            120.0             Fantasy
# 3                            100.0             Mystery
# 4                            100.0         Family saga
# ..                             ...                 ...
# 169                           10.0             Fantasy
# 170                           10.0             Fantasy
# 171                           10.0             Fantasy
# 172                           10.0             Fantasy
# 173                           10.0             Fantasy
#
# [174 rows x 6 columns]

# %%
zi =df['Original language'].value_counts()
zi
# Out:
# Original language
# English       131
# Russian         6
# French          5
# German          5
# Japanese        5
# Chinese         4
# Italian         4
# Spanish         3
# Hindi           2
# Norwegian       2
# Swedish         2
# Portuguese      1
# Dutch           1
# Czech           1
# Yiddish         1
# Gujarati        1
# Name: count, dtype: int64

# %% [markdown]
# # Visualization

# %%
df.plot(kind='line')
plt.title('count of best selling books')
plt.xlabel('book')
plt.ylabel('count')
plt.show()

# %%
sns.heatmap(h,annot=True)
plt.title('describe of best selling books data')
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
df
# Out:
#                                                   Book  \
# 0                                 A Tale of Two Cities
# 1                  The Little Prince (Le Petit Prince)
# 2             Harry Potter and the Philosopher's Stone
# 3                             And Then There Were None
# 4                       Dream of the Red Chamber (紅樓夢)
# ..                                                 ...
# 169                                           The Goal
# 170                                     Fahrenheit 451
# 171                                     Angela's Ashes
# 172  The Story of My Experiments with Truth (સત્યના...
# 173                              Bridget Jones's Diary
#
#                       Author(s) Original language  First published  \
# 0               Charles Dickens           English             1859
# 1      Antoine de Saint-Exupéry            French             1943
# 2                 J. K. Rowling           English             1997
# 3               Agatha Christie           English             1939
# 4                    Cao Xueqin           Chinese             1791
# ..                          ...               ...              ...
# 169         Eliyahu M. Goldratt           English             1984
# 170                Ray Bradbury           English             1953
# 171               Frank McCourt           English             1996
# 172  Mohandas Karamchand Gandhi          Gujarati             1929
# 173              Helen Fielding           English             1996
#
#      Approximate sales in millions               Genre
# 0                            200.0  Historical fiction
# 1                            200.0             Novella
# 2                            120.0             Fantasy
# 3                            100.0             Mystery
# 4                            100.0         Family saga
# ..                             ...                 ...
# 169                           10.0             Fantasy
# 170                           10.0             Fantasy
# 171                           10.0             Fantasy
# 172                           10.0             Fantasy
# 173                           10.0             Fantasy
#
# [174 rows x 6 columns]

# %%
pd.DataFrame(df['Genre'].value_counts()).plot(kind='bar', figsize=(10, 10))
# Out:
# <Axes: xlabel='Genre'>

# %%
plt.figure(figsize=(10,10))
sns.distplot(df['Approximate sales in millions'],color='red')
plt.title('Approximate sales in millions')
plt.show()

# %%
plt.figure(figsize=(40,10))
sns.barplot(x="Book",y="Approximate sales in millions",data=df,palette='icefire')
plt.xticks(rotation=90)
plt.show()

# %%
sns.jointplot(x='Original language',y='Approximate sales in millions',data=df,alpha=0.5)
plt.xticks(rotation=90)
plt.show()

# %%
sales_by_genre = df.groupby('Genre')['Approximate sales in millions'].sum().reset_index()
plt.figure(figsize=(20, 5))
sns.barplot(data=sales_by_genre, x='Genre', y='Approximate sales in millions')
plt.xlabel('Genre')
plt.ylabel('Total Sales (millions)')
plt.title('Sales by Genre')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.barplot(data=df, x='Original language', y='Approximate sales in millions')
plt.xlabel('Original Language')
plt.ylabel('Total Sales (millions)')
plt.title('Sales by Original Language')
plt.xticks(rotation=45)
plt.show()

# %%
top_authors = df.groupby('Author(s)')['Approximate sales in millions'].sum().nlargest(10)
plt.figure(figsize=(10, 6))
top_authors.plot(kind='bar')
plt.xlabel('Author')
plt.ylabel('Total Sales (millions)')
plt.title('Top Authors by Sales')
plt.xticks(rotation=45)
plt.show()

# %%
top_books = df.sort_values(by='Approximate sales in millions', ascending=False).head(20)


plt.figure(figsize=(10, 6))
plt.bar(top_books['Genre'], top_books['Approximate sales in millions'], color='pink')
plt.xticks(rotation=45)
plt.xlabel('Genre')
plt.ylabel('Approximate Sales (in millions)')
plt.title('Top 20 Books by genre')
plt.show()

# %%
top_books = df.sort_values(by='Approximate sales in millions', ascending=False).head(20)


plt.figure(figsize=(10, 6))
plt.bar(top_books['Book'], top_books['Approximate sales in millions'], color='skyblue')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Book')
plt.ylabel('Approximate Sales (in millions)')
plt.title('Top 20 Best-Selling Books')
plt.show()

# %%
df.groupby('Book')['Approximate sales in millions'].mean().sort_values(ascending=False).head(20)
# Out:
# Book
# The Little Prince (Le Petit Prince)          200.0
# A Tale of Two Cities                         200.0
# Harry Potter and the Philosopher's Stone     120.0
# The Hobbit                                   100.0
# Dream of the Red Chamber (紅樓夢)               100.0
# And Then There Were None                     100.0
# The Lion, the Witch and the Wardrobe          85.0
# She: A History of Adventure                   83.0
# Vardi Wala Gunda (वर्दी वाला गुंडा)           80.0
# The Da Vinci Code                             80.0
# Harry Potter and the Chamber of Secrets       77.0
# The Alchemist (O Alquimista)                  65.0
# Harry Potter and the Order of the Phoenix     65.0
# The Catcher in the Rye                        65.0
# Harry Potter and the Goblet of Fire           65.0
# Harry Potter and the Prisoner of Azkaban      65.0
# Harry Potter and the Half-Blood Prince        65.0
# Harry Potter and the Deathly Hallows          65.0
# The Bridges of Madison County                 60.0
# You Can Heal Your Life                        50.0
# Name: Approximate sales in millions, dtype: float64

# %%
z=df.groupby('Author(s)')['Book'].count().sort_values(ascending=False).head(20)
z
# Out:
# Author(s)
# J. K. Rowling                 7
# Suzanne Collins               3
# Dan Brown                     3
# Roald Dahl                    3
# Ken Follett                   2
# E. L. James                   2
# Erskine Caldwell              2
# George Orwell                 2
# Albert Camus                  2
# Patricia Nell Warren          1
# Paramahansa Yogananda         1
# Patrick Süskind               1
# Mikhail Sholokhov             1
# Norman Vincent Peale          1
# Nikolai Ostrovsky             1
# Nicholas Evans                1
# Nelson Mandela                1
# Mohandas Karamchand Gandhi    1
# Paula Hawkins                 1
# Mitch Albom                   1
# Name: Book, dtype: int64

# %%
recommended_Book = df.pivot_table(index='Author(s)',columns='Book',values='Approximate sales in millions')
recommended_Book
# Out:
# Book                             A Brief History of Time  A Message to Garcia  \
# Author(s)
# Agatha Christie                                      NaN                  NaN
# Albert Camus                                         NaN                  NaN
# Alex Comfort                                         NaN                  NaN
# Alexander Alexandrovich Fadeyev                      NaN                  NaN
# Alice Sebold                                         NaN                  NaN
# ...                                                  ...                  ...
# William Peter Blatty                                 NaN                  NaN
# Xaviera Hollander                                    NaN                  NaN
# Xue Muqiao                                           NaN                  NaN
# Yann Martel                                          NaN                  NaN
# Yu Dan                                               NaN                  NaN
#
# Book                             A Tale of Two Cities  A Wrinkle in Time  \
# Author(s)
# Agatha Christie                                   NaN                NaN
# Albert Camus                                      NaN                NaN
# Alex Comfort                                      NaN                NaN
# Alexander Alexandrovich Fadeyev                   NaN                NaN
# Alice Sebold                                      NaN                NaN
# ...                                               ...                ...
# William Peter Blatty                              NaN                NaN
# Xaviera Hollander                                 NaN                NaN
# Xue Muqiao                                        NaN                NaN
# Yann Martel                                       NaN                NaN
# Yu Dan                                            NaN                NaN
#
# Book                             Adventures of Huckleberry Finn  \
# Author(s)
# Agatha Christie                                             NaN
# Albert Camus                                                NaN
# Alex Comfort                                                NaN
# Alexander Alexandrovich Fadeyev                             NaN
# Alice Sebold                                                NaN
# ...                                                         ...
# William Peter Blatty                                        NaN
# Xaviera Hollander                                           NaN
# Xue Muqiao                                                  NaN
# Yann Martel                                                 NaN
# Yu Dan                                                      NaN
#
# Book                             Alcoholics Anonymous Big Book  \
# Author(s)
# Agatha Christie                                            NaN
# Albert Camus                                               NaN
# Alex Comfort                                               NaN
# Alexander Alexandrovich Fadeyev                            NaN
# Alice Sebold                                               NaN
# ...                                                        ...
# William Peter Blatty                                       NaN
# Xaviera Hollander                                          NaN
# Xue Muqiao                                                 NaN
# Yann Martel                                                NaN
# Yu Dan                                                     NaN
#
# Book                             All Quiet on the Western Front (Im Westen nichts Neues)  \
# Author(s)
# Agatha Christie                                                                NaN
# Albert Camus                                                                   NaN
# Alex Comfort                                                                   NaN
# Alexander Alexandrovich Fadeyev                                                NaN
# Alice Sebold                                                                   NaN
# ...                                                                            ...
# William Peter Blatty                                                           NaN
# Xaviera Hollander                                                              NaN
# Xue Muqiao                                                                     NaN
# Yann Martel                                                                    NaN
# Yu Dan                                                                         NaN
#
# Book                             All the Light We Cannot See  \
# Author(s)
# Agatha Christie                                          NaN
# Albert Camus                                             NaN
# Alex Comfort                                             NaN
# Alexander Alexandrovich Fadeyev                          NaN
# Alice Sebold                                             NaN
# ...                                                      ...
# William Peter Blatty                                     NaN
# Xaviera Hollander                                        NaN
# Xue Muqiao                                               NaN
# Yann Martel                                              NaN
# Yu Dan                                                   NaN
#
# Book                             And Then There Were None  \
# Author(s)
# Agatha Christie                                     100.0
# Albert Camus                                          NaN
# Alex Comfort                                          NaN
# Alexander Alexandrovich Fadeyev                       NaN
# Alice Sebold                                          NaN
# ...                                                   ...
# William Peter Blatty                                  NaN
# Xaviera Hollander                                     NaN
# Xue Muqiao                                            NaN
# Yann Martel                                           NaN
# Yu Dan                                                NaN
#
# Book                             Andromeda Nebula (Туманность Андромеды)  ...  \
# Author(s)                                                                 ...
# Agatha Christie                                                      NaN  ...
# Albert Camus                                                         NaN  ...
# Alex Comfort                                                         NaN  ...
# Alexander Alexandrovich Fadeyev                                      NaN  ...
# Alice Sebold                                                         NaN  ...
# ...                                                                  ...  ...
# William Peter Blatty                                                 NaN  ...
# Xaviera Hollander                                                    NaN  ...
# Xue Muqiao                                                           NaN  ...
# Yann Martel                                                          NaN  ...
# Yu Dan                                                               NaN  ...
#
# Book                             Watership Down  \
# Author(s)
# Agatha Christie                             NaN
# Albert Camus                                NaN
# Alex Comfort                                NaN
# Alexander Alexandrovich Fadeyev             NaN
# Alice Sebold                                NaN
# ...                                         ...
# William Peter Blatty                        NaN
# Xaviera Hollander                           NaN
# Xue Muqiao                                  NaN
# Yann Martel                                 NaN
# Yu Dan                                      NaN
#
# Book                             What Color Is Your Parachute?  \
# Author(s)
# Agatha Christie                                            NaN
# Albert Camus                                               NaN
# Alex Comfort                                               NaN
# Alexander Alexandrovich Fadeyev                            NaN
# Alice Sebold                                               NaN
# ...                                                        ...
# William Peter Blatty                                       NaN
# Xaviera Hollander                                          NaN
# Xue Muqiao                                                 NaN
# Yann Martel                                                NaN
# Yu Dan                                                     NaN
#
# Book                             What to Expect When You're Expecting  \
# Author(s)
# Agatha Christie                                                   NaN
# Albert Camus                                                      NaN
# Alex Comfort                                                      NaN
# Alexander Alexandrovich Fadeyev                                   NaN
# Alice Sebold                                                      NaN
# ...                                                               ...
# William Peter Blatty                                              NaN
# Xaviera Hollander                                                 NaN
# Xue Muqiao                                                        NaN
# Yann Martel                                                       NaN
# Yu Dan                                                            NaN
#
# Book                             Where the Crawdads Sing  \
# Author(s)
# Agatha Christie                                      NaN
# Albert Camus                                         NaN
# Alex Comfort                                         NaN
# Alexander Alexandrovich Fadeyev                      NaN
# Alice Sebold                                         NaN
# ...                                                  ...
# William Peter Blatty                                 NaN
# Xaviera Hollander                                    NaN
# Xue Muqiao                                           NaN
# Yann Martel                                          NaN
# Yu Dan                                               NaN
#
# Book                             Where the Wild Things Are  \
# Author(s)
# Agatha Christie                                        NaN
# Albert Camus                                           NaN
# Alex Comfort                                           NaN
# Alexander Alexandrovich Fadeyev                        NaN
# Alice Sebold                                           NaN
# ...                                                    ...
# William Peter Blatty                                   NaN
# Xaviera Hollander                                      NaN
# Xue Muqiao                                             NaN
# Yann Martel                                            NaN
# Yu Dan                                                 NaN
#
# Book                             Who Moved My Cheese?  Wild Swans  \
# Author(s)
# Agatha Christie                                   NaN         NaN
# Albert Camus                                      NaN         NaN
# Alex Comfort                                      NaN         NaN
# Alexander Alexandrovich Fadeyev                   NaN         NaN
# Alice Sebold                                      NaN         NaN
# ...                                               ...         ...
# William Peter Blatty                              NaN         NaN
# Xaviera Hollander                                 NaN         NaN
# Xue Muqiao                                        NaN         NaN
# Yann Martel                                       NaN         NaN
# Yu Dan                                            NaN         NaN
#
# Book                             Wolf Totem (狼图腾)  You Can Heal Your Life  \
# Author(s)
# Agatha Christie                               NaN                     NaN
# Albert Camus                                  NaN                     NaN
# Alex Comfort                                  NaN                     NaN
# Alexander Alexandrovich Fadeyev               NaN                     NaN
# Alice Sebold                                  NaN                     NaN
# ...                                           ...                     ...
# William Peter Blatty                          NaN                     NaN
# Xaviera Hollander                             NaN                     NaN
# Xue Muqiao                                    NaN                     NaN
# Yann Martel                                   NaN                     NaN
# Yu Dan                                        NaN                     NaN
#
# Book                             Your Erroneous Zones
# Author(s)
# Agatha Christie                                   NaN
# Albert Camus                                      NaN
# Alex Comfort                                      NaN
# Alexander Alexandrovich Fadeyev                   NaN
# Alice Sebold                                      NaN
# ...                                               ...
# William Peter Blatty                              NaN
# Xaviera Hollander                                 NaN
# Xue Muqiao                                        NaN
# Yann Martel                                       NaN
# Yu Dan                                            NaN
#
# [157 rows x 174 columns]

# %%
# Group by 'Author(s)' and calculate total number of books and total sales
author_stats = df.groupby('Author(s)').agg(
    Total_Books=('Book', 'size'),
    Total_Sales_Millions=('Approximate sales in millions', 'sum')
).reset_index()

# Sort by 'Total Books' in descending order
author_stats = author_stats.sort_values(by='Total_Books', ascending=False)

author_stats.head(10)
# Out:
#              Author(s)  Total_Books  Total_Sales_Millions
# 58       J. K. Rowling            7                 522.0
# 26           Dan Brown            3                 149.0
# 139    Suzanne Collins            3                  70.0
# 125         Roald Dahl            3                  65.0
# 43    Erskine Caldwell            2                  24.0
# 1         Albert Camus            2                  22.0
# 83         Ken Follett            2                  25.0
# 48       George Orwell            2                  50.0
# 34         E. L. James            2                  25.6
# 103  Mikhail Sholokhov            1                  24.0

# %%
# Filter the dataset for books authored by J.K. Rowling
jk_rowling_books = df[df['Author(s)'] == 'J. K. Rowling']

# Show J.K. Rowling's books along with their sales in millions
jk_rowling_books_sales_in_millions = jk_rowling_books[['Author(s)','Book', 'Approximate sales in millions','Genre']]
jk_rowling_books_sales_in_millions
# Out:
#         Author(s)                                       Book  \
# 2   J. K. Rowling   Harry Potter and the Philosopher's Stone
# 10  J. K. Rowling    Harry Potter and the Chamber of Secrets
# 11  J. K. Rowling   Harry Potter and the Prisoner of Azkaban
# 12  J. K. Rowling        Harry Potter and the Goblet of Fire
# 13  J. K. Rowling  Harry Potter and the Order of the Phoenix
# 14  J. K. Rowling     Harry Potter and the Half-Blood Prince
# 15  J. K. Rowling       Harry Potter and the Deathly Hallows
#
#     Approximate sales in millions    Genre
# 2                           120.0  Fantasy
# 10                           77.0  Fantasy
# 11                           65.0  Fantasy
# 12                           65.0  Fantasy
# 13                           65.0  Fantasy
# 14                           65.0  Fantasy
# 15                           65.0  Fantasy

# %%
info_data = jk_rowling_books_sales_in_millions.pivot_table(index='Book',columns='Author(s)',values='Approximate sales in millions')
info_data
# Out:
# Author(s)                                  J. K. Rowling
# Book
# Harry Potter and the Chamber of Secrets             77.0
# Harry Potter and the Deathly Hallows                65.0
# Harry Potter and the Goblet of Fire                 65.0
# Harry Potter and the Half-Blood Prince              65.0
# Harry Potter and the Order of the Phoenix           65.0
# Harry Potter and the Philosopher's Stone           120.0
# Harry Potter and the Prisoner of Azkaban            65.0

# %%
info_data['sales_in_millions'] = pd.DataFrame(df.groupby('Book')['Approximate sales in millions'].sum())
info_data
# Out:
# Author(s)                                  J. K. Rowling  sales_in_millions
# Book
# Harry Potter and the Chamber of Secrets             77.0               77.0
# Harry Potter and the Deathly Hallows                65.0               65.0
# Harry Potter and the Goblet of Fire                 65.0               65.0
# Harry Potter and the Half-Blood Prince              65.0               65.0
# Harry Potter and the Order of the Phoenix           65.0               65.0
# Harry Potter and the Philosopher's Stone           120.0              120.0
# Harry Potter and the Prisoner of Azkaban            65.0               65.0

# %%
info_data.groupby('Book')['sales_in_millions'].mean().sort_values(ascending=False).head(7)
# Out:
# Book
# Harry Potter and the Philosopher's Stone     120.0
# Harry Potter and the Chamber of Secrets       77.0
# Harry Potter and the Deathly Hallows          65.0
# Harry Potter and the Goblet of Fire           65.0
# Harry Potter and the Half-Blood Prince        65.0
# Harry Potter and the Order of the Phoenix     65.0
# Harry Potter and the Prisoner of Azkaban      65.0
# Name: sales_in_millions, dtype: float64

# %%
Harry_Potter = info_data.loc["Harry Potter and the Chamber of Secrets":]
Harry_Potter
# Out:
# Author(s)                                  J. K. Rowling  sales_in_millions
# Book
# Harry Potter and the Chamber of Secrets             77.0               77.0
# Harry Potter and the Deathly Hallows                65.0               65.0
# Harry Potter and the Goblet of Fire                 65.0               65.0
# Harry Potter and the Half-Blood Prince              65.0               65.0
# Harry Potter and the Order of the Phoenix           65.0               65.0
# Harry Potter and the Philosopher's Stone           120.0              120.0
# Harry Potter and the Prisoner of Azkaban            65.0               65.0

# %%
similar_to_Harry_Potter = info_data.corrwith(Harry_Potter)

# %%
corr_Harry_Potter = pd.DataFrame(similar_to_Harry_Potter,columns=['Correlation'])
corr_Harry_Potter
# Out:
#                    Correlation
# Author(s)
# J. K. Rowling              1.0
# sales_in_millions          1.0

# %%
corr_Harry_Potter = pd.concat([corr_Harry_Potter, info_data['sales_in_millions']], axis=1) # Use pd.concat to join the DataFrame and Series. Use axis=1 to concatenate along columns
corr_Harry_Potter.sort_values(by='Correlation', ascending=False)
# Out:
#                                            Correlation  sales_in_millions  \
# J. K. Rowling                                      1.0                NaN
# sales_in_millions                                  1.0                NaN
# Harry Potter and the Chamber of Secrets            NaN                NaN
# Harry Potter and the Deathly Hallows               NaN                NaN
# Harry Potter and the Goblet of Fire                NaN                NaN
# Harry Potter and the Half-Blood Prince             NaN                NaN
# Harry Potter and the Order of the Phoenix          NaN                NaN
# Harry Potter and the Philosopher's Stone           NaN                NaN
# Harry Potter and the Prisoner of Azkaban           NaN                NaN
#
#                                            sales_in_millions  \
# J. K. Rowling                                            NaN
# sales_in_millions                                        NaN
# Harry Potter and the Chamber of Secrets                 77.0
# Harry Potter and the Deathly Hallows                    65.0
# Harry Potter and the Goblet of Fire                     65.0
# Harry Potter and the Half-Blood Prince                  65.0
# Harry Potter and the Order of the Phoenix               65.0
# Harry Potter and the Philosopher's Stone               120.0
# Harry Potter and the Prisoner of Azkaban                65.0
#
#                                            sales_in_millions  \
# J. K. Rowling                                            NaN
# sales_in_millions                                        NaN
# Harry Potter and the Chamber of Secrets                 77.0
# Harry Potter and the Deathly Hallows                    65.0
# Harry Potter and the Goblet of Fire                     65.0
# Harry Potter and the Half-Blood Prince                  65.0
# Harry Potter and the Order of the Phoenix               65.0
# Harry Potter and the Philosopher's Stone               120.0
# Harry Potter and the Prisoner of Azkaban                65.0
#
#                                            sales_in_millions  \
# J. K. Rowling                                            NaN
# sales_in_millions                                        NaN
# Harry Potter and the Chamber of Secrets                 77.0
# Harry Potter and the Deathly Hallows                    65.0
# Harry Potter and the Goblet of Fire                     65.0
# Harry Potter and the Half-Blood Prince                  65.0
# Harry Potter and the Order of the Phoenix               65.0
# Harry Potter and the Philosopher's Stone               120.0
# Harry Potter and the Prisoner of Azkaban                65.0
#
#                                            sales_in_millions  \
# J. K. Rowling                                            NaN
# sales_in_millions                                        NaN
# Harry Potter and the Chamber of Secrets                 77.0
# Harry Potter and the Deathly Hallows                    65.0
# Harry Potter and the Goblet of Fire                     65.0
# Harry Potter and the Half-Blood Prince                  65.0
# Harry Potter and the Order of the Phoenix               65.0
# Harry Potter and the Philosopher's Stone               120.0
# Harry Potter and the Prisoner of Azkaban                65.0
#
#                                            sales_in_millions
# J. K. Rowling                                            NaN
# sales_in_millions                                        NaN
# Harry Potter and the Chamber of Secrets                 77.0
# Harry Potter and the Deathly Hallows                    65.0
# Harry Potter and the Goblet of Fire                     65.0
# Harry Potter and the Half-Blood Prince                  65.0
# Harry Potter and the Order of the Phoenix               65.0
# Harry Potter and the Philosopher's Stone               120.0
# Harry Potter and the Prisoner of Azkaban                65.0

# %%
corr_Harry_Potter[corr_Harry_Potter['sales_in_millions']>65].sort_values('Correlation',ascending=False)
# Out:
#                                           Correlation  sales_in_millions
# Harry Potter and the Chamber of Secrets           NaN               77.0
# Harry Potter and the Philosopher's Stone          NaN              120.0

# %%
corr_Harry_Potter = pd.DataFrame(similar_to_Harry_Potter,columns=['Correlation'])
corr_Harry_Potter = corr_Harry_Potter.join(corr_Harry_Potter['sales_in_millions'])
corr_Harry_Potter[corr_Harry_Potter['sales_in_millions']>65].sort_values('Correlation',ascending=False)
